# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from datetime import date
project_name = 'ambient_2023'
print(project_name+ " last ran on " + date.today().strftime("%B %d, %Y"))
# Out:
# ambient_2023 last ran on June 22, 2022

# %%
# load libraries
import awqmn

import pandas as pd
from dataretrieval import nwis, wqp
from dataretrieval.utils import format_datetime

import numpy as np

from sqlalchemy import types

# %%
# helper functions
import datetime

def validate_date(date_text):
    try:
        return datetime.datetime.strptime(date_text, '%Y-%m-%d')
    except ValueError:
        return np.nan

def validate_time(date_text):
    try:
        return datetime.datetime.strptime(date_text, '%H:%M')
    except ValueError:
        return np.nan

def validate_df(df):
    df = df.copy()
    for column in df.columns:
        if column.endswith('_dt'):
            df[column] = df[column].astype(str).apply(validate_date)
        if column.endswith('_tm'):
            df[column] = df['sample_dt'].astype(str).apply(validate_time)
            
    return df

# %%
#setup database
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:Qwert213@localhost/postgres')

# %%
#sites

# %%
#0 load site info from excel table
filename='../data/ambient_sites_v2023.csv'
sites = pd.read_csv(filename, dtype={'USGS Code':str, 'USGS Gage':str})
sites = sites.dropna(subset=['USGS Gage']) #drop any site without associated streamgage
sites['StoretCode'] = 'IL_EPA_WQX-' + sites['StationCode']
#storet_id = 'IL_EPA_WQX-' + sites['StationCode']
#usgs_sites = sites['USGS Code']
#usgs_sites = usgs_sites[~usgs_sites.isna()].values.tolist()

# setup dtype (this should go in repo)
df,_ = wqp.get_results(siteid='IL_EPA_WQX-ATF-08')

from sqlalchemy import String, Numeric, Time, Date
dtype = {columns : String for columns in df}

for column in df.columns:
    if "MeasureValue" in column:
        dtype[column] = Numeric
    if "PrecisionValue" in column:
        dtype[column] = Numeric
    if column.endswith("Date"):
        dtype[column] = Date
    if column.endswith("Time"):
        dtype[column] = Time

# %%
sites.head()
# Out:
#    Unnamed: 0 SamplerOffice StationCode      StreamName  \
# 1           2           CMU        D-05  Illinois River
# 3           4           CMU        D-32  Illinois River
# 4           5           CMU       DA-06  Macoupin Creek
# 7           8           CMU       DG-01  La Moine River
# 8           9           CMU       DG-04  La Moine River
#
#                                             Location Pesticide Chlorophyll  \
# 1                          Rm 152.9 At Sr 9 At Pekin       NaN           X
# 3           Rm 61.4 At Rr Br 0.5 Mi E Of Valley City       NaN           X
# 4                        Rt 267 Br 3.5 Mi NW of Kane       NaN         NaN
# 7  Old US 24 (1500E) br, 0.2 mi E of US 24 and 0....       NaN         NaN
# 8  SR 61 br, 0.9 mi S of St Marys Rd (1000N) and ...       NaN         NaN
#
#       LatDD    LongDD      TopoMapName Topo75Num USGS Code      AUID     HUC8  \
# 1  40.57370 -89.65514        Pekin, IL      108C  05563800   IL_D-05  7130003
# 3  39.70329 -90.64580  Griggsville, IL      169B  05586100   IL_D-32  7130011
# 4  39.23424 -90.39454  Boyer Creek, IL      198B  05587000  IL_DA-06  7130012
# 7  40.02480 -90.63144       Ripley, IL      137C  05585000  IL_DG-01  7130010
# 8  40.33088 -90.89613     Plymouth, IL      130C  05584500  IL_DG-04  7130010
#
#          HUC10 USGS Gage        StoretCode
# 1  713000303.0  05568500   IL_EPA_WQX-D-05
# 3  713001108.0  05586100   IL_EPA_WQX-D-32
# 4  713001206.0  05587000  IL_EPA_WQX-DA-06
# 7  713001012.0  05585000  IL_EPA_WQX-DG-01
# 8  713001007.0  05584500  IL_EPA_WQX-DG-04

# %%
#1 download wqp data and upload to db
for index, site in sites.iterrows():
    #print(site)
    df,_ = wqp.get_results(siteid=site['StoretCode'])
    df = df[df['ActivityTypeCode'] != 'Field Msr/Obs']
    df.to_sql('wqp', con=engine, schema=project_name, if_exists='append', index=False, dtype=dtype)
    

#collect all raw data from Water Quality Portal
#for site in storet_id:
#    df,_ = wqp.get_results(siteid=site)
    #df = df[df['ResultMeasureValue'] != 'N']
#    df = df[df['ActivityTypeCode'] != 'Field Msr/Obs']
#    df.to_sql('wqp', con=engine, schema=project_name, if_exists='append', index=False, dtype=dtype)
    #print(site) if crashes
# Out:
# c:\users\thodson\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3361: DtypeWarning: Columns (13,39,42) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# c:\users\thodson\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3361: DtypeWarning: Columns (22) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# c:\users\thodson\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3361: DtypeWarning: Columns (13,22,39,42) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# c:\users\thodson\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3361: DtypeWarning: Columns (22,33,39,42) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# c:\users\thodson\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3361: DtypeWarning: Columns (39,42) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# c:\users\thodson\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3361: DtypeWarning: Columns (22,26,27,28,29,39,42) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
#2 download alternate sites data from STORET and upload to db with name change
#TODO define dtype
#TODO read info directly from csv
old_sites = {#new : old
             'ATF-08':'ATF-04',
             'BEF-05':'BEF-03',
             'E-18':'E-28',
             'EO-03':'EO-01',
             'DT-01':'DT-46',
             'F-16':'F-01',
             'GB-10':'GB-16',
             'K-22':'K-04',
             'M-12':'M-04',
             'N-06':'M-10',
             'OI-07':'OI-09'
}
            #note aready had BEF-03, flipped it with BEF-05


# NOTE for this analysis new sites are associated with old for trends and loads
for new, old in old_sites.items():
    old_id = 'IL_EPA_WQX-' + old
    new_id = 'IL_EPA_WQX-' + new
    df,_ = wqp.get_results(siteid=old_id)
    df['MonitoringLocationIdentifier'] = new_id
    df.to_sql('wqp', con=engine, schema=project_name, if_exists='append', index=False, dtype=dtype)
    #print(old)

# %%
#3 download nwis samples from qwdata
# Two approaches:
# 1. go site by site, concat a list of columns and initialize table in database
# 2. go site by site and concat everything into one dataframe, then push to database

# NOTE: when not limited to IL-EPA data, the query generates too many fields for the database. Need to cull down to this list:
param_list = [
    '00665', #Total P
    '00666',
    '00667',
    '00530', #VOC?
    '00535',
    '00625',
    '00610',
    '00600', #TN
    '00631', #NO3
    '00400', #pH
    #'00910', #Ca
    '00915', #Ca mg
    '99220', #Cl
    '91051', #Ca ug
    '91052', #Mg ug
    '00946', #Sulfate
    '80154' #SSC
]

from awqmn.db.dtypes import qwdata as qwdata_dtype
from dataretrieval.utils import NoSitesError
# find all column names


df = pd.DataFrame()

def good_data(df):
    '''
    '''
    if df.columns[0] == '<!DOCTYPE html>':
        return False
    else:
        return True
#for site in usgs_sites:
for index, site in sites.iterrows():
    try:
        #break
        temp,_ = nwis.get_qwdata(datetime_index=False, sites=site['USGS Code'], wide_format=False,  medium_cd='WS', parameterCd=param_list) #param was commented

        # every site should have a USGS gage ( added this if)
        if site['USGS Code'] != site['USGS Gage']:
            temp2,_ = nwis.get_qwdata(datetime_index=False, sites=site['USGS Gage'], wide_format=False,  medium_cd='WS', parameterCd=param_list)
            if good_data(df):
                temp = temp.append(temp2)
        # drop all non IL-EPA data
        #df = df[df['coll_ent_cd']=='IL-EPA']
        
        if not temp.empty:
            #df = pd.concat([df,temp], axis=0, ignore_index=True)
            temp = validate_df(temp)
            temp = temp.dropna(subset=['sample_dt'])
            #temp['prep_dt'] = np.nan
            #temp['anl_dt'] = np.nan
            temp.to_sql('qwdata', con=engine, schema=project_name, if_exists='append', index=False, dtype=qwdata_dtype)

        
    except (TypeError, NoSitesError) as e:
        print(e)
        print(site)
        
    except TimeoutError:
        print('Timeout at {}'.format(site))
        
    except Exception as e:
        print(e)
        print('Other at {}'.format(site))


#df.to_sql('qwdata', con=engine, schema='nrec', if_exists='replace', index=False, dtype=qwdata_dtype)
# Out:
# index 0 is out of bounds for axis 0 with size 0
# Other at Unnamed: 0                               2
# SamplerOffice                          CMU
# StationCode                           D-05
# StreamName                  Illinois River
# Location         Rm 152.9 At Sr 9 At Pekin
# Pesticide                              NaN
# Chlorophyll                              X
# LatDD                              40.5737
# LongDD                           -89.65514
# TopoMapName                      Pekin, IL
# Topo75Num                             108C
# USGS Code                         05563800
# AUID                               IL_D-05
# HUC8                               7130003
# HUC10                          713000303.0
# USGS Gage                         05568500
# StoretCode                 IL_EPA_WQX-D-05
# Name: 1, dtype: object
# index 0 is out of bounds for axis 0 with size 0
# Other at Unnamed: 0                                                      13
# SamplerOffice                                                  CMU
# StationCode                                                  DK-12
# StreamName                                          Mackinaw River
# Location         Wagonseller  Rd (1200E) br, 0.3 mi N of Weir R...
# Pesticide                                                      NaN
# Chlorophyll                                                    NaN
# LatDD                                                     40.44746
# LongDD                                                   -89.69103
# TopoMapName                                        South Pekin, IL
# Topo75Num                                                     125B
# USGS Code                                                 05568005
# AUID                                                      IL_DK-12
# HUC8                                                       7130004
# HUC10                                                  713000408.0
# USGS Gage                                                 05568000
# StoretCode                                        IL_EPA_WQX-DK-12
# Name: 12, dtype: object
# index 0 is out of bounds for axis 0 with size 0
# Other at Unnamed: 0                                 17
# SamplerOffice                             CMU
# StationCode                             EL-01
# StreamName                  Spring Creek-West
# Location         Bruns Lane Br NW Springfield
# Pesticide                                 NaN
# Chlorophyll                               NaN
# LatDD                                  39.821
# LongDD                              -89.68702
# TopoMapName              Springfield West, IL
# Topo75Num                                158C
# USGS Code                            05577505
# AUID                                 IL_EL-01
# HUC8                                  7130008
# HUC10                             713000802.0
# USGS Gage                            05577500
# StoretCode                   IL_EPA_WQX-EL-01
# Name: 16, dtype: object
# index 0 is out of bounds for axis 0 with size 0
# Other at Unnamed: 0                                  26
# SamplerOffice                         SMU_ISWS
# StationCode                              BE-01
# StreamName                      Embarras River
# Location         Cr 620 N, 1.3 Mi E Of Billett
# Pesticide                                  NaN
# Chlorophyll                                NaN
# LatDD                                 38.66493
# LongDD                               -87.62639
# TopoMapName                  Lawrenceville, IL
# Topo75Num                                 235B
# USGS Code                             03346550
# AUID                                  IL_BE-01
# HUC8                                   5120112
# HUC10                              512011215.0
# USGS Gage                             03346500
# StoretCode                    IL_EPA_WQX-BE-01
# Name: 25, dtype: object
# index 0 is out of bounds for axis 0 with size 0
# Other at Unnamed: 0                                              29
# SamplerOffice                                     CMU_ISWS
# StationCode                                          BE-14
# StreamName                                  Embarras River
# Location         Cr 1000 N (Main St) Br, W Edge Of Camargo
# Pesticide                                              NaN
# Chlorophyll                                            NaN
# LatDD                                             39.79973
# LongDD                                           -88.17041
# TopoMapName                                Villa Grove, IL
# Topo75Num                                             152C
# USGS Code                                         03343395
# AUID                                              IL_BE-14
# HUC8                                               5120112
# HUC10                                          512011201.0
# USGS Gage                                         03343400
# StoretCode                                IL_EPA_WQX-BE-14
# Name: 28, dtype: object
# index 0 is out of bounds for axis 0 with size 0
# Other at Unnamed: 0                                42
# SamplerOffice                       SMU_ISWS
# StationCode                             C-23
# StreamName               Little Wabash River
# Location         Sr 1 Br (Main St), In Carmi
# Pesticide                                NaN
# Chlorophyll                                X
# LatDD                               38.09233
# LongDD                             -88.15624
# TopoMapName                        Carmi, IL
# Topo75Num                               258C
# USGS Code                           03381495
# AUID                                 IL_C-23
# HUC8                                 5120114
# HUC10                            512011410.0
# USGS Gage                           03381500
# StoretCode                   IL_EPA_WQX-C-23
# Name: 41, dtype: object
# index 0 is out of bounds for axis 0 with size 0
# Other at Unnamed: 0                                       46
# SamplerOffice                              CMU_ISWS
# StationCode                                   DS-06
# StreamName                          Vermilion River
# Location         Cr 1400 N Br, 0.5 Mi E Of Mcdowell
# Pesticide                                         X
# Chlorophyll                                     NaN
# LatDD                                      40.83055
# LongDD                                    -88.57514
# TopoMapName                   Southeast Pontiac, IL
# Topo75Num                                      090D
# USGS Code                                  05554490
# AUID                                       IL_DS-06
# HUC8                                        7130002
# HUC10                                   713000203.0
# USGS Gage                                  05554500
# StoretCode                         IL_EPA_WQX-DS-06
# Name: 45, dtype: object
# index 0 is out of bounds for axis 0 with size 0
# Other at Unnamed: 0                                      82
# SamplerOffice                                  SMU
# StationCode                                   N-12
# StreamName                         Big Muddy River
# Location         Sr 127 Br SE edge of  Murphysboro
# Pesticide                                      NaN
# Chlorophyll                                      X
# LatDD                                     37.75787
# LongDD                                   -89.32728
# TopoMapName                        Murphysboro, IL
# Topo75Num                                     265D
# USGS Code                                 05599500
# AUID                                       IL_N-12
# HUC8                                       7140106
# HUC10                                  714010612.0
# USGS Gage                                 05599490
# StoretCode                         IL_EPA_WQX-N-12
# Name: 81, dtype: object
# index 0 is out of bounds for axis 0 with size 0
# Other at Unnamed: 0                            102
# SamplerOffice                         NMU
# StationCode                         DT-35
# StreamName                      Fox River
# Location         Sr 173 Br 4 Mi E Antioch
# Pesticide                             NaN
# Chlorophyll                             X
# LatDD                            42.47899
# LongDD                           -88.1785
# TopoMapName               Fox Lake, IL-WI
# Topo75Num                            008B
# USGS Code                        05546700
# AUID                             IL_DT-35
# HUC8                              7120006
# HUC10                         712000610.0
# USGS Gage                        05545750
# StoretCode               IL_EPA_WQX-DT-35
# Name: 101, dtype: object
# index 0 is out of bounds for axis 0 with size 0
# Other at Unnamed: 0                                   117
# SamplerOffice                           NMU-USGS
# StationCode                                DT-01
# StreamName                             Fox River
# Location         Sr 71-Us 6Br, Ne Edge Of Ottawa
# Pesticide                                    NaN
# Chlorophyll                                    X
# LatDD                                   41.35626
# LongDD                                 -88.82757
# TopoMapName                           Ottawa, IL
# Topo75Num                                   061D
# USGS Code                               05553000
# AUID                                    IL_DT-01
# HUC8                                     7120007
# HUC10                                712000706.0
# USGS Gage                               05552500
# StoretCode                      IL_EPA_WQX-DT-01
# Name: 116, dtype: object

# %%
#nwis.get_qwdata(datetime_index=False, sites='05568500', wide_format=False,  medium_cd='WS', parameterCd=param_list)

# %%
#4 download alternate sites data from NWIS and upload
from awqmn.db.dtypes import qwdata as qwdata_dtype

old_sites = {#new : old
             #'03382325':'03382325',
             '05572000':'05572125',
             #'05576000':'05576022',
             '05553000':'05552500',
             '05593800':'05593785'
}


for new, old in old_sites.items():
    try:
        df,_ = nwis.get_qwdata(datetime_index=False, site_no=old, wide_format=False)# parameterCd=param_list)
        #df = df[df['coll_ent_cd']=='IL-EPA']
        df['site_no'] = new
        if not df.empty:
            df['prep_dt'] = np.nan
            df['anl_dt'] = np.nan
            df.to_sql('qwdata', con=engine, schema=project_name, if_exists='append', index=False, dtype=qwdata_dtype)

        
    except (TypeError, NoSitesError):
        print(site)
        
    except TimeoutError:
        print('Timeout at {}'.format(site))
        
    except:
        print('Other at {}'.format(site))
# Out:
# <ipython-input-47-f04a2b69f954>:15: DtypeWarning: Columns (4,5,15,17,25,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   df,_ = nwis.get_qwdata(datetime_index=False, site_no=old, wide_format=False)# parameterCd=param_list)

# %%
#Verify that this works as expected and 05586300 gets converted to 05586100

#4b: sites like Florence, where we want to associate the data with the old site (Valley City)
old_sites = {#new : old
#XXX DELETE ME
             '05586300':'05586100', #Florence : Valley City
             '05599490':'05590500' #big muddy
}

for new, old in old_sites.items():
    try:
        df,_ = nwis.get_qwdata(datetime_index=False, site_no=new, wide_format=False)# parameterCd=param_list)
        #df = df[df['coll_ent_cd']=='IL-EPA']
        df['site_no'] = old
        if not df.empty:
            df['prep_dt'] = np.nan
            df['anl_dt'] = np.nan
            df.to_sql('qwdata', con=engine, schema=project_name, if_exists='append', index=False, dtype=qwdata_dtype)

        
    except (TypeError, NoSitesError):
        print(site)
        
    except TimeoutError:
        print('Timeout at {}'.format(site))
        
    except:
        print('Other at {}'.format(site))
# Out:
# <ipython-input-48-495a43597d92>:12: DtypeWarning: Columns (14,16,27) have mixed types.Specify dtype option on import or set low_memory=False.
#   df,_ = nwis.get_qwdata(datetime_index=False, site_no=new, wide_format=False)# parameterCd=param_list)
